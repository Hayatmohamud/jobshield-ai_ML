# %% [markdown]
# 1) Imorts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

plt.style.use("ggplot")
pd.set_option("display.max_columns", None)

# %% [markdown]
# 2) Load Dataset

# %%
from pathlib import Path
import pandas as pd

DATA_PATH = Path("../dataset/raw/fake_job_postings.csv")

print(DATA_PATH.exists())

df = pd.read_csv(DATA_PATH)
df.head()
# Out:
# True
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI – Environmental Systems Rese...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  telecommuting  \
# 0                                                NaN              0
# 1  What you will get from usThrough being part of...              0
# 2                                                NaN              0
# 3  Our culture is anything but corporate—we have ...              0
# 4                              Full Benefits Offered              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
# 2                 1              0             NaN                 NaN
# 3                 1              0       Full-time    Mid-Senior level
# 4                 1              1       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#    fraudulent
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# 3) Shape

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 17880
# Columns: 18

# %% [markdown]
# 4) Column Names

# %%
df.columns.tolist()
# Out:
# ['job_id',
#  'title',
#  'location',
#  'department',
#  'salary_range',
#  'company_profile',
#  'description',
#  'requirements',
#  'benefits',
#  'telecommuting',
#  'has_company_logo',
#  'has_questions',
#  'employment_type',
#  'required_experience',
#  'required_education',
#  'industry',
#  'function',
#  'fraudulent']

# %% [markdown]
# 5) Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  str
#  2   location             17534 non-null  str
#  3   department           6333 non-null   str
#  4   salary_range         2868 non-null   str
#  5   company_profile      14572 non-null  str
#  6   description          17879 non-null  str
#  7   requirements         15184 non-null  str
#  8   benefits             10668 non-null  str
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  str
#  13  required_experience  10830 non-null  str
#  14  required_education   9775 non-null   str
#  15  industry             12977 non-null  str
#  16  function             11425 non-null  str
#  17  fraudulent           17880 non-null  int64
# dtypes: int64(5), str(13)
# memory usage: 2.5 MB

# %% [markdown]
# 6) Missing Values

# %%
missing = (
    df.isnull()
      .sum()
      .sort_values(ascending=False)
)

missing[missing > 0]
# Out:
# salary_range           15012
# department             11547
# required_education      8105
# benefits                7212
# required_experience     7050
# function                6455
# industry                4903
# employment_type         3471
# company_profile         3308
# requirements            2696
# location                 346
# description                1
# dtype: int64

# %% [markdown]
# 7) Duplicate Rows

# %%
duplicates = df.duplicated().sum()

print("Duplicate rows:", duplicates)
# Out:
# Duplicate rows: 0

# %% [markdown]
# 8) Target Distribution

# %%
df["fraudulent"].value_counts()
# Out:
# fraudulent
# 0    17014
# 1      866
# Name: count, dtype: int64

# %%
df["fraudulent"].value_counts().plot(
    kind="bar"
)

plt.title("Real vs Fake Jobs")
plt.xlabel("Fraudulent")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# 9) Statistical Summary

# %%
df.describe(include="all").T
# Out:
#                        count unique  \
# job_id               17880.0    NaN
# title                  17880  11231
# location               17534   3105
# department              6333   1337
# salary_range            2868    874
# company_profile        14572   1709
# description            17879  14801
# requirements           15184  11967
# benefits               10668   6204
# telecommuting        17880.0    NaN
# has_company_logo     17880.0    NaN
# has_questions        17880.0    NaN
# employment_type        14409      5
# required_experience    10830      7
# required_education      9775     13
# industry               12977    131
# function               11425     37
# fraudulent           17880.0    NaN
#
#                                                                    top   freq  \
# job_id                                                             NaN    NaN
# title                                          English Teacher Abroad     311
# location                                               GB, LND, London    718
# department                                                       Sales    551
# salary_range                                                       0-0    142
# company_profile      We help teachers get safe &amp; secure jobs ab...    726
# description          Play with kids, get paid for it Love travel? J...    379
# requirements         University degree required. TEFL / TESOL / CEL...    410
# benefits                                           See job description    726
# telecommuting                                                      NaN    NaN
# has_company_logo                                                   NaN    NaN
# has_questions                                                      NaN    NaN
# employment_type                                              Full-time  11620
# required_experience                                   Mid-Senior level   3809
# required_education                                   Bachelor's Degree   5145
# industry                           Information Technology and Services   1734
# function                                        Information Technology   1749
# fraudulent                                                         NaN    NaN
#
#                          mean          std  min      25%     50%       75%  \
# job_id                 8940.5  5161.655742  1.0  4470.75  8940.5  13410.25
# title                     NaN          NaN  NaN      NaN     NaN       NaN
# location                  NaN          NaN  NaN      NaN     NaN       NaN
# department                NaN          NaN  NaN      NaN     NaN       NaN
# salary_range              NaN          NaN  NaN      NaN     NaN       NaN
# company_profile           NaN          NaN  NaN      NaN     NaN       NaN
# description               NaN          NaN  NaN      NaN     NaN       NaN
# requirements              NaN          NaN  NaN      NaN     NaN       NaN
# benefits                  NaN          NaN  NaN      NaN     NaN       NaN
# telecommuting        0.042897     0.202631  0.0      0.0     0.0       0.0
# has_company_logo     0.795302     0.403492  0.0      1.0     1.0       1.0
# has_questions        0.491723     0.499945  0.0      0.0     0.0       1.0
# employment_type           NaN          NaN  NaN      NaN     NaN       NaN
# required_experience       NaN          NaN  NaN      NaN     NaN       NaN
# required_education        NaN          NaN  NaN      NaN     NaN       NaN
# industry                  NaN          NaN  NaN      NaN     NaN       NaN
# function                  NaN          NaN  NaN      NaN     NaN       NaN
# fraudulent           0.048434     0.214688  0.0      0.0     0.0       0.0
#
#                          max
# job_id               17880.0
# title                    NaN
# location                 NaN
# department               NaN
# salary_range             NaN
# company_profile          NaN
# description              NaN
# requirements             NaN
# benefits                 NaN
# telecommuting            1.0
# has_company_logo         1.0
# has_questions            1.0
# employment_type          NaN
# required_experience      NaN
# required_education       NaN
# industry                 NaN
# function                 NaN
# fraudulent               1.0
